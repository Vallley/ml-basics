# %%
import numpy as np
from past.utils import native
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt

columns = 'age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(
    ',')
# df = pd.read_csv('../../data/adult.csv.gz', na_values='?') # можно загрузить из файла или URL
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', na_values='?',
                 names=columns)

df.tail(10)  # выводит последние n строк

#print(df.shape)
#print(df.dtypes)

#df.at[12, 'sex'] = np.nan

#print(df.isnull().sum())#isnull -возвращает таблицу где false - есть значение, true - значение = Nan, sum - зозвращает итог true

#print(df['workclass'].value_counts())#считает количество значений

print(df[df['sex'].str.strip() == 'Male']['age'].mean(skipna=True))
print(df[df['sex'].str.strip() == 'Female']['age'].mean(skipna=True))

df.head()

#fig, axes = plt.subplots(1, 1, figsize=(5, 10))
#axes.bar(df['capital.loss'], df['education'])
#fig.show()
'''
print(df[df['income'].str.strip() == '<=50K']['age'].mean())
print(df[df['income'].str.strip() == '>50K']['age'].mean())
print(df[df['income'].str.strip() == '<=50K']['age'].std())
print(df[df['income'].str.strip() == '>50K']['age'].std())

print(df[(df['income'].str.strip() == '>50K')]['education'].str.strip().isin(('Bachelors', 'Prof-school', 'Assoc-acdm', 'Assoc-voc', 'Masters', 'Doctorate')).all())

#print(df.dtypes)

print(df[(df['income'].str.strip() == '>50K') & (df['marital.status'].str.strip().str.startswith('Married'))].shape[0])
print(df[(df['income'].str.strip() == '>50K') & ~(df['marital.status'].str.strip().str.startswith('Married'))].shape[0])

for country in df['native.country'].unique():
    print(country)
    print(df[(df['income'].str.strip()=='>50K') & (df['native.country'] == country)]['hours.per.week'].mean())
    print(df[(df['income'].str.strip()=='<=50K') & (df['native.country'] == country)]['hours.per.week'].mean())'''

'''df['dif'] = df['capital.gain'] - df['capital.loss']

# Преобразование в категориальный признак с помощью кубического корня
df['passive_income'] = (np.sign(df['dif']) * np.power(abs(df['dif']), 1/3) * 2).round().astype(int)
df['passive_income'] = pd.cut(df['passive_income'], bins=10)
data = pd.DataFrame({'education': df['education'], 'passive_income': df['passive_income']})

print(df[(df['income'].str.strip() == '>50K')]['native.country'].count())

female = pd.DataFrame()

df_female = df[df['sex'].str.strip() == 'Female']

df_female['high_income'] = (df_female['income'].str.strip() == '>50K').astype(int)


print(df_female.groupby('native.country')['high_income'].count().sort_values(ascending=False))'''
magic_df = df.copy()
magic_salary = np.zeros(len(df))

mask = df['income'].str.strip() == '<=50K'
magic_salary[mask] = np.random.randint(51, size=mask.sum())
magic_salary[~mask] = np.random.randint(51, 101, size=(~mask).sum())

magic_df['magic_salary'] = magic_salary

print(magic_df.groupby('education')['magic_salary'].mean() / magic_df['hours.per.week'])

#print(magic_df)
# Out:
# 39.43354749885268
# 36.85823043357163
#  10th      NaN
#  11th      NaN
#  12th      NaN
#  1st-4th   NaN
#  5th-6th   NaN
#             ..
# 32556      NaN
# 32557      NaN
# 32558      NaN
# 32559      NaN
# 32560      NaN
# Length: 32577, dtype: float64
