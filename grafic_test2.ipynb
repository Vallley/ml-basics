# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('./train.csv')

df['datetime'] = pd.to_datetime(df['datetime'])

df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month


'''fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 12))
for idx, feature in enumerate(df.columns[:-1]):
     df.plot(feature, 'count', subplots=True, kind="scatter", ax=axes[idx // 4, idx % 4])
'''

'''
corr = df.corr()
#print(corr)
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")

df.head()'''
'''
data = df.groupby(['year', 'month'])['count'].sum()
df_data = data.reset_index(name = 'count')
print(df_data)

sns.barplot(
    data = df_data,
    x = 'month',
    y = 'count',
    hue = 'year',
    dodge = True,
)'''

df.head()
'''
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.countplot(data=df, x='workingday', ax=ax[0])
ax[0].set_title("Workingday Countplot")

sns.countplot(data=df, x='weather', ax=ax[1])
ax[1].set_title("Weather Countplot")

plt.figure(figsize=(6,6))
sns.histplot(df['count'], bins=100, kde=True)
'''

sns.jointplot(data=df, x='temp', y='atemp', kind='scatter')
sns.jointplot(data=df, x='temp', y='atemp', kind='hex')
sns.jointplot(data=df, x='temp', y='atemp', kind='kde')

df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month
# 0        81        0.0       3          13     16  2011      1
# 1        80        0.0       8          32     40  2011      1
# 2        80        0.0       5          27     32  2011      1
# 3        75        0.0       3          10     13  2011      1
# 4        75        0.0       0           1      1  2011      1
